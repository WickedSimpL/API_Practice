# %%
import requests

url = "https://covid-19-data.p.rapidapi.com/country"

querystring = {"name":"USA","format":"json"}

headers = {
	"x-rapidapi-key": "e61bec14f5msh450b3d09000a6f9p1dd46fjsn576954f4418a",
	"x-rapidapi-host": "covid-19-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
json_data = response.json()
print(json_data[0].get('confirmed'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 14
#      12 response = requests.get(url, headers=headers, params=querystring)
#      13 json_data = response.json()
# ---> 14 print(json_data['headers'].get('confirmed'))
#
# TypeError: list indices must be integers or slices, not str
